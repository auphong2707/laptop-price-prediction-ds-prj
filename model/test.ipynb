# %%
import sklearn 
import joblib
import pandas as pd

# %%
model = joblib.load('/home/quangminh/Documents/code/Python/ProjectDS/laptop-price-prediction-ds-prj/model.joblib')

# %%
model
# Out:
# DecisionTreeRegressor(max_depth=10, random_state=42)

# %%
data = pd.read_csv('/home/quangminh/Documents/code/Python/ProjectDS/laptop-price-prediction-ds-prj/model/test_processed.csv')

# %%
data
# Out:
#      brand  ram_amount  ram_type storage_amount  storage_type  \
# 0        2          16         4            512             2
# 1        4           8         3            512             2
# 2        5          12         4            512             2
# 3        4          16         4            512             2
# 4        1          16         4            512             2
# ..     ...         ...       ...            ...           ...
# 225      2          16         4           1024             2
# 226      5          16         4            512             2
# 227      2           8         4            512             2
# 228      4           8         4            512             2
# 229      5          12         4            512             2
#
#      webcam_resolution  screen_size screen_resolution  screen_refresh_rate  \
# 0                    0         14.0         1920x1200                180.0
# ...

# %%
X_test = data.drop('price', axis=1)
y_test = data['price']

y_test
# Out:
# 0      15990000
# 1      11590000
# 2      17790000
# 3      16590000
# 4      25990000
#          ...
# 225    19990000
# 226    21290000
# 227    15290000
# 228    14990000
# 229    16990000
# Name: price, Length: 230, dtype: int64

# %%
y_pred = model.predict(X_test) 
y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 y_pred = model.predict(X_test)
#       2 y_pred
#
# File ~/anaconda3/envs/ProjectDS/lib/python3.12/site-packages/sklearn/tree/_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 """Predict class or regression value for X.
#     507
#     508 For a classification model, the predicted class for each sample in X is
#    (...)
#     526     The predicted classes, or the predict values.
#     527 """
#     528 check_is_fitted(self)
# --> 529 X = self._validate_X_predict(X, check_input)
#     530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#
# File ~/anaconda3/envs/ProjectDS/lib/python3.12/site-packages/sklearn/tree/_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     force_all_finite = True
# ...
